# %% [markdown]
# ------
# ### Exercise 6 - Markov Chain Monte Carlo

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import factorial
from collections import Counter
from scipy import stats

# %% [markdown]
# ###  1 - Metropolis-Hastings
#
# $P(i) = c \cdot \frac{A^i}{i!},\ i = 0,...,m$
#
# Generating values from this distribution by applying the Metropolis-Hastings algorithm,

# %%
def actual_dist1():
    p = np.array([8**i/factorial(i) for i in range(11)])
    return p/sum(p)

def make_dist(sample):
    
    n = len(sample)
    c = [(k, v) for k,v in Counter(sample).items()]
    c = sorted(c, key = lambda x: x[0])
    dist = []
    indices = []
    for x in c:
        
        i, count = x[0], x[1]
        indices.append(i)
        dist.append(count/n)

    return dist


def metropolis_hastings(n=10000, A=8, m=10):
    
    g = lambda x: (A**x)/factorial(x)

    X = np.zeros(n)
    
    for i in range(n-1):

        
        x_current = X[i]

        x_proposed = np.random.randint(0, m + 1)
        
        acceptance_probability = min(1, g(x_proposed)/g(x_current))

        u = np.random.uniform(0,1)
        
        if u <= acceptance_probability:
            X[i+1] = x_proposed
        else:
            X[i+1] = x_current
    return X

# %% [markdown]
# Simulating values, and finding probability distribution

# %%
X = metropolis_hastings()

X_dist = make_dist(X)
plt.scatter(list(range(11)),X_dist, marker="x", color="g")
plt.grid()
plt.xlabel(r"$i$")
plt.title("Distribution of truncated poisson")
plt.ylabel(r"$P(X=i)$")
plt.show()

plt.hist(vals, bins=11, color="g", alpha=0.5)
plt.title("Histogram: Metropolis Hastings")
plt.grid()
plt.show()

# %% [markdown]
# Verifying visually and with $\chi^2$:

# %%
from scipy.stats import chisquare

plt.scatter(list(range(11)),actual_dist1(), marker="x", label="Actual")
plt.scatter(list(range(11)),X_dist, marker="x",label="Generated", color="g")
plt.grid()
plt.xlabel(r"$i$")
plt.title("Comparison between Probability distributions")
plt.legend(loc='upper left')
plt.ylabel(r"$P(X=i)$")
plt.show() 

# Proceeding with chi-2 test

chisq, p = chisquare(f_obs=[i*10000 for i in X_dist], f_exp=[i*10000 for i in actual_dist()])
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# Test statistic: 55859.88459108814
# P-value: 0.0

# %% [markdown]
# Attempting to generate more acceptable sample, by thinning generated sample

# %%
thinned_sample = thin(vals, 5)

thinned_indices, thinned_pdf = make_pdf(thinned_sample)

plt.scatter([i for i in range(0, 11)],true_pdf(8, 10), marker="x", label="Actual")
plt.scatter(thinned_indices,thinned_pdf, marker="x",label="Generated")
plt.grid()
plt.xlabel(r"$i$")
plt.title("Comparison between Probability distributions - After thinning")
plt.legend(loc='upper left')
plt.ylabel(r"$P(X=i)$")
plt.show() 

chisq, p = chisquare(f_obs=[i*len(thinned_sample) for i in pdf], f_exp=[i*len(thinned_sample) for i in true_pdf(8, 10)])
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# Test statistic: 4.35201333654848
# P-value: 0.9300730922129283

# %% [markdown]
# Thinning has increased the *p-value* dramatically

# %% [markdown]
# ### 2 - Joint Distribution
#
#
#
# $P(i,j) = c \cdot \frac{A^{i}_{1}}{i!} \frac{A^{j}_{2}}{j!}, \ 0 \leq i+j \leq m$
#
# where $A_1, \ A_2 = 4 \text{ and } m = 10$

# %% [markdown]
# #### (a) Using Metropolis-Hastings Directly

# %%
def actual_dist2():
    
    A1, A2 = 4, 4
    
    m = 10

    g = lambda x, y: ((A1**x)/factorial(x)) * ((A2**y)/factorial(y))
    
    p = np.zeros(m+1)

    for i in range(11):
        for(j) in range(11):
            if i+j <= m:
                p[i+j] = g(i, j)
    return p/sum(p)




def MH2(n=10000, m=10):

    A1, A2 = 4, 4
    
    g = lambda x, y: ((A1**x)/factorial(x)) * ((A2**y)/factorial(y))

    
    
    X, Y = np.zeros(n), np.zeros(n)

    for i in range(n-1):
        
        current_X, current_Y = X[i], Y[i]
        
        proposed_X = np.random.randint(0, m+1)
        proposed_Y = np.random.randint(0, m+1-proposed_X)
        
        acceptance_probability = min(1, g(proposed_X, proposed_Y)/g(current_X, current_Y))

        u = np.random.uniform()
        
        if u <= acceptance_probability:
            
            X[i+1], Y[i+1] = proposed_X, proposed_Y
        
        else:
        
            X[i+1], Y[i+1] = current_X, current_Y

    return X, Y

# %%
plt.scatter(list(range(11)), actual_dist())
plt.show()

# %% [markdown]
# Simulating sample

# %%
X1, Y1 = MH2()

X1_p = make_dist(X1)
Y1_p = make_dist(Y1)



plt.hist2d(X1, Y1)
plt.title("2-D Histogram for MH values")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

plt.scatter(list(range(11)), X1_p, label= "Generated (X)")
plt.scatter(list(range(11)),Y1_p, label="Generated (Y)")
plt.scatter(list(range(11)),[i for i in actual_dist()], marker="x", label="Actual")
plt.ylabel("Count")
plt.grid()
plt.xlabel(r"$i$")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Conducting $\chi^2$ test

# %%
chisq, p = chisquare(f_obs=[i*10000 for i in X1_p], f_exp=[i*10000 for i in actual_dist2()])
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# Test statistic: 211.53442379330988
# P-value: 6.304567324812798e-40

# %% [markdown]
# Thinning sample and performing $\chi^2$ test

# %%
X1_thin_3 = thin(X1, 3)
X1_thin_3_dist = make_dist(X1_thin_3)
chisq, p = chisquare(f_obs=[i*10000 for i in X1_thin_3_dist], f_exp=[i*10000 for i in actual_dist()])
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# Test statistic: 212.7940846528162
# P-value: 3.4382572067832715e-40

# %%
plt.scatter(list(range(11)), X1_thin_3_dist, marker="x", label="Simulated (Thinned, 3)",alpha=0.5)
plt.scatter(list(range(11)), X1_p, marker="x", label="Simulated (no thinning)",alpha=0.5)
plt.scatter(list(range(11)), actual_dist(), marker="x", label="Actual")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Despite thinning, samples fail $\chi^2$ at a $5\%$ significance level

# %% [markdown]
# #### (b) Metropolis-Hastings Coordinate-Wise

# %% [markdown]
# Creating probability matrix

# %%
def create_probability_matrix(A1=4, A2=4, m=10):
    
    g = lambda i, j: ((A1**i)/factorial(i)) * ((A2**j)/factorial(j))
    M = np.zeros(shape=(m+1, m+1))
    s = 0

    for i in range(m+1):
        for j in range(m+1):
            if i+j <=m:
                M[i][j] = g(i, j)
                s += g(i, j)

    return M/s

# %% [markdown]
# Coordinate-wise Metropolis-Hastings

# %%
def MH_coord(n=10000, m=10, A1=4, A2=4):

    g = lambda i, j: ((A1**i)/factorial(i)) * ((A2**j)/factorial(j))

    X, Y = np.zeros(n), np.zeros(n)
    
    Y[0] = np.random.randint(0, m + 1)
    
    M = create_probability_matrix()
    
    for i in range(n):        
        
        x_probability = M[int(Y[i])] / sum(M[int(Y[i])]) # Probabilities of moving to a different x
        new_x = np.random.choice(list(range(11)), p=x_probability)
        
        y_probability = M[:,int(new_x)] / sum(M[:,int(new_x)])
        new_y = np.random.choice(list(range(11)), p=y_probability)
        
        X[i] = new_x
        Y[i] = new_y

    return (X, Y)

# %% [markdown]
# Generating sample

# %%
X_c, Y_c = MH_coord(10000)

# %% [markdown]
# Verifying visually

# %%
X_c_dist = make_dist(X_c)
Y_c_dist = make_dist(Y_c)


plt.hist2d(X_c, Y_c)
plt.title("2-D Histogram for MH coordinate-wise values")
plt.xlabel("x")
plt.ylabel("y")
plt.show()


plt.scatter(list(range(11)), X_c_dist, marker="x", color="m", label="Generated (X)")
plt.scatter(list(range(11)),actual_dist(), marker="x", label="Actual")
plt.ylabel(r"$P(X=i)$")
plt.xlabel(r"i")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Performing $\chi^2$ test on X generated by MH coordinate-wise

# %%
chisq, p = chisquare(f_obs=[i*10000 for i in X_c_dist], f_exp=[i*10000 for i in actual_dist()])
print("chi squared test: X")
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# chi squared test: X
# Test statistic: 15.289000983835908
# P-value: 0.12187525895512866

# %% [markdown]
# #### (c) Use Gibbs sampling

# %%
def gibbs(n, A1=4, A2=4, m=10):

    X, Y = np.zeros(n), np.zeros(n)

    g = lambda i, j: ((A1**i)/factorial(i)) * ((A2**j)/factorial(j))
    M = create_probability_matrix()
    
    # Functions for calculating conditional probability

    px_given_y = lambda x, y: M[y][x]/sum(M[y])
    py_given_x = lambda x, y: M[y][x]/sum(M[:, x])
    
    # Randomly selecting start state
    
    X[0], Y[0] = np.random.randint(0, m+1), np.random.randint(0, m+1)

    for i in range(n-1):

        current_y = int(Y[i])

        # Updating x 

        vals = [px_given_y(j, current_y) for j in range(m+1)]
        probabilities = [val/sum(vals) for val in vals] # Distribution of conditional probabilities P(X=i|current Y) 
        new_X = np.random.choice([l for l in range(m+1)], size=1, replace=True, p=probabilities)[0]

        # Updating y

        vals = [py_given_x(new_X, j) for j in range(m+1)]
        probabilities = [val/sum(vals) for val in vals] # Distribution of conditional probabilities P(Y=j|new X)
        new_Y = np.random.choice([l for l in range(m+1)], size=1, replace=True, p=probabilities)[0]

        # Inserting into samples
        X[i+1], Y[i+1] = new_X, new_Y
    
    return X, Y

# %% [markdown]
# Obtaining samples

# %%
X_gibbs, Y_gibbs = gibbs(10000)

# %% [markdown]
# Displaying distributions

# %%
X_gibbs_dist = make_dist(X_gibbs)


plt.scatter(i_X_gibbs, X_gibbs_pdf, marker="x", color="c", label="Gibbs (X)")
plt.scatter([i for i in range(0, 11)],actual_dist(), marker="x", label="Actual")
plt.grid()
plt.ylabel(r"$P(X=i)$")
plt.xlabel(r"$i$")
plt.show()

# %% [markdown]
# Performing $\chi^2$ test

# %%
chisq, p = chisquare(f_obs=[i*10000 for i in X_gibbs_dist], f_exp=[i*10000 for i in actual_dist()])
print(f"Test statistic: {chisq}")
print(f"P-value: {p}")
# Out:
# Test statistic: 628.3313613179977
# P-value: 1.4912459180747724e-128

# %% [markdown]
# ### 3 - Bayesian Problem
#
# - Omitted due to difficulty and time restrictions.
