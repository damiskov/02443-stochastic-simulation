# %%
import numpy as np
import matplotlib.pyplot as plt
from SIR import SIR
from simple_SIR import test_disease, measure_effect_of_beta_gamma, measure_effect_of_total_population, measure_effect_of_starting_infected

# %% [markdown]
# #### Simulating disease progression in populations of 1000 for various diseases
# - Dashed line = Average curve for particular group from stochastic model (after running 50 times)
# - Solid line = ODE model
# - Transparent lines = results of stochastic model

# %%
test_disease("Ebola", 0.4, 0.3, 100)
test_disease("COVID-19", 0.4, 0.2, 100)
test_disease("Influenza", 1/3, 1/7, 200)
test_disease("Measles", 0.9, 0.2, 100)
# Out:
# MSE S: 13339.619471901351
# MSE I: 136.95819326979435
# MSE R: 13080.173239846212
# MSE S: 2202.3284904459924
# MSE I: 211.1772020625693
# MSE R: 4586.744072540826
# MSE S: 917.5774232831013
# MSE I: 109.90481428449527
# MSE R: 3882.3865038215504
# MSE S: 113.76397148645894
# MSE I: 1364.7673763792884
# MSE R: 33439.45795407677

# %% [markdown]
# #### Analysing effect of $\beta$, $\gamma$, population size and starting infected population on model

# %%
test_disease("Test 1", 0.5, 0.02, 200)
test_disease("Test 2", 0.5, 0.2, 200)
# Out:
# MSE S: 15.7025256842623
# MSE I: 4384.046968010927
# MSE R: 18537.528730358623
# MSE S: 1259.8154018119649
# MSE I: 171.24102486151128
# MSE R: 8462.011519073552

# %%
measure_effect_of_beta_gamma()

# %%
measure_effect_of_total_population()
measure_effect_of_starting_infected()
